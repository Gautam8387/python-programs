# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# Feature Run
num_features = [10, 100, 1000, 10000, 100000]
time_taken_wall = [0.061, 0.203, 0.502, 0.840, 5.2]
time_taken_usr = [0.043, 0.375, 1.2, 1.48, 5.82]
time_taken_sys = [0.012, 0.94, 0.171, 0.252, 0.170]

feature_run = pd.DataFrame({'Number of Features': num_features, 'Wall Time (s)': time_taken_wall, 'User Time (s)': time_taken_usr, 'System Time (s)': time_taken_sys })
feature_run
# Out:
#    Number of Features  Wall Time (s)  User Time (s)  System Time (s)
# 0                  10          0.061          0.043            0.012
# 1                 100          0.203          0.375            0.940
# 2                1000          0.502          1.200            0.171
# 3               10000          0.840          1.480            0.252
# 4              100000          5.200          5.820            0.170

# %%
# Plot
sns.set_theme(style='whitegrid')
plt.figure(figsize=(7, 5))
sns.lineplot(x='Number of Features', y='Wall Time (s)', data=feature_run, color='red')
plt.title('Feature Run Time')
plt.xlabel('Number of Features (log10)')
plt.ylabel('Time Taken (seconds)')
plt.xscale('log')
# Plot red dots at the data points
plt.scatter(num_features, time_taken_wall, color='black')

# Dotted plots for User and System Time
plt.plot(num_features, time_taken_usr, linestyle='dotted', color='black')
plt.plot(num_features, time_taken_sys, linestyle='dotted', color='green')

legend_data = {'Wall Time': 'red', 'User Time': 'black', 'System Time': 'green'}
legend_labels = list(legend_data.keys())
legend_handles = [plt.Line2D([0], [0], color=color, marker='o', linestyle='') for color in legend_data.values()]
plt.legend(legend_handles, legend_labels, title='Time Type', loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Row

# %%
# Feature Run
num_rows = [10, 100, 1000, 10000, 100000, 1000000, 10000000]
time_taken_wall = [0.062, 0.385, 5.3, 75, 1300, '-', '-']
time_taken_usr = [0.042, 0.295, 4.42, 62, 1122, '-', '-']
time_taken_sys = [0.019, 0.089, 0.827, 13.3, 177, '-', '-']

# Convert '-' to NaN for easier handling
time_taken_wall = [x if x != '-' else np.nan for x in time_taken_wall]
time_taken_usr = [x if x != '-' else np.nan for x in time_taken_usr]
time_taken_sys = [x if x != '-' else np.nan for x in time_taken_sys]

row_run = pd.DataFrame({'Number of Rows': num_rows, 'Wall Time (s)': time_taken_wall, 'User Time (s)': time_taken_usr, 'System Time (s)': time_taken_sys })
row_run
# Out:
#    Number of Rows  Wall Time (s)  User Time (s)  System Time (s)
# 0              10          0.062          0.042            0.019
# 1             100          0.385          0.295            0.089
# 2            1000          5.300          4.420            0.827
# 3           10000         75.000         62.000           13.300
# 4          100000       1300.000       1122.000          177.000
# 5         1000000            NaN            NaN              NaN
# 6        10000000            NaN            NaN              NaN

# %%
plt.figure(figsize=(7, 5))
sns.lineplot(x='Number of Rows', y='Wall Time (s)', data=row_run, color='red')
plt.title('Row Run Time')
plt.xlabel('Number of Rows (log10)')
plt.ylabel('Time Taken (seconds)')
plt.xscale('log')
# Plot red dots at the data points
plt.scatter(num_rows, time_taken_wall, color='black')

# Dotted plots for User and System Time
plt.plot(num_rows, time_taken_usr, linestyle='dotted', color='black')
plt.plot(num_rows, time_taken_sys, linestyle='dotted', color='green')

legend_data = {'Wall Time': 'red', 'User Time': 'black', 'System Time': 'green'}
legend_labels = list(legend_data.keys())
legend_handles = [plt.Line2D([0], [0], color=color, marker='o', linestyle='') for color in legend_data.values()]
plt.legend(legend_handles, legend_labels, title='Time Type', loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Mix

# %%
# Feature Run
mix_ = [(10,10), (100,100), (1000,1000), (10000,10000)]
mix_vals = [10, 100, 1000, 10000]
time_taken_wall = [0.078, 2.97, 57.7, 1212]
time_taken_usr = [0.062, 4.89, 68, 1911]
time_taken_sys = [0.001, 1.11, 18.5, 190]

mix_run = pd.DataFrame({'Dimensions': mix_, 'Wall Time (s)': time_taken_wall, 'User Time (s)': time_taken_usr, 'System Time (s)': time_taken_sys , 'Number of Features': mix_vals})
mix_run
# Out:
#        Dimensions  Wall Time (s)  User Time (s)  System Time (s)  \
# 0        (10, 10)          0.078          0.062            0.001
# 1      (100, 100)          2.970          4.890            1.110
# 2    (1000, 1000)         57.700         68.000           18.500
# 3  (10000, 10000)       1212.000       1911.000          190.000
#
#    Number of Features
# 0                  10
# 1                 100
# 2                1000
# 3               10000

# %%
plt.figure(figsize=(7, 5))
sns.lineplot(x='Number of Features', y='Wall Time (s)', data=mix_run, color='red')
plt.title('Mixed Run Time')
plt.xlabel('Feature and Row Dimensions (log10)')
plt.ylabel('Time Taken (seconds)')
plt.xscale('log')
# Plot red dots at the data points
plt.scatter([x[0] for x in mix_], time_taken_wall, color='black')

# Dotted plots for User and System Time
plt.plot([x[0] for x in mix_], time_taken_usr, linestyle='dotted', color='black')
plt.plot([x[0] for x in mix_], time_taken_sys, linestyle='dotted', color='green')

legend_data = {'Wall Time': 'red', 'User Time': 'black', 'System Time': 'green'}
legend_labels = list(legend_data.keys())
legend_handles = [plt.Line2D([0], [0], color=color, marker='o', linestyle='') for color in legend_data.values()]
plt.legend(legend_handles, legend_labels, title='Time Type', loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Version 2
# Row wise dumping

# %% [markdown]
# ## Feature

# %%
# Feature Run
num_features = [10, 100, 1000, 10000, 100000]
time_taken_wall = [0.032, 0.042, 0.086, 0.343, 4.76]
time_taken_usr = [0.012, 0.039, 0.118, 0.370, 4.67]
time_taken_sys = [0.011, 0.027, 0.026, 0.060, 0.163]

feature_run = pd.DataFrame({'Number of Features': num_features, 'Wall Time (s)': time_taken_wall, 'User Time (s)': time_taken_usr, 'System Time (s)': time_taken_sys })
feature_run
# Out:
#    Number of Features  Wall Time (s)  User Time (s)  System Time (s)
# 0                  10          0.032          0.012            0.011
# 1                 100          0.042          0.039            0.027
# 2                1000          0.086          0.118            0.026
# 3               10000          0.343          0.370            0.060
# 4              100000          4.760          4.670            0.163

# %%
plt.figure(figsize=(7, 5))
sns.lineplot(x='Number of Features', y='Wall Time (s)', data=feature_run, color='red')
plt.title('Feature Run Time')
plt.xlabel('Number of Features (log10)')
plt.ylabel('Time Taken (seconds)')
plt.xscale('log')

# Plot red dots at the data points
plt.scatter(num_features, time_taken_wall, color='black')

# Dotted plots for User and System Time
plt.plot(num_features, time_taken_usr, linestyle='dotted', color='black')
plt.plot(num_features, time_taken_sys, linestyle='dotted', color='green')

legend_data = {'Wall Time': 'red', 'User Time': 'black', 'System Time': 'green'}
legend_labels = list(legend_data.keys())
legend_handles = [plt.Line2D([0], [0], color=color, marker='o', linestyle='') for color in legend_data.values()]
plt.legend(legend_handles, legend_labels, title='Time Type', loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Row

# %%
row_run = [10, 100, 1000, 10000, 100000, 1000000, 10000000]
time_taken_wall = [0.027, 0.240, 0.714, 13.8, 586, '-', '-']
time_taken_usr = [0.017, 0.154, 0.664, 13.1, 555, '-', '-']
time_taken_sys = [0.009, 0.049, 0.050, 0.739, 31.4, '-', '-']

# Convert '-' to NaN for easier handling
time_taken_wall = [x if x != '-' else np.nan for x in time_taken_wall]
time_taken_usr = [x if x != '-' else np.nan for x in time_taken_usr]
time_taken_sys = [x if x != '-' else np.nan for x in time_taken_sys]

row_run = pd.DataFrame({'Number of Rows': num_rows, 'Wall Time (s)': time_taken_wall, 'User Time (s)': time_taken_usr, 'System Time (s)': time_taken_sys })
row_run
# Out:
#    Number of Rows  Wall Time (s)  User Time (s)  System Time (s)
# 0              10          0.027          0.017            0.009
# 1             100          0.240          0.154            0.049
# 2            1000          0.714          0.664            0.050
# 3           10000         13.800         13.100            0.739
# 4          100000        586.000        555.000           31.400
# 5         1000000            NaN            NaN              NaN
# 6        10000000            NaN            NaN              NaN

# %%
plt.figure(figsize=(7, 5))
sns.lineplot(x='Number of Rows', y='Wall Time (s)', data=row_run, color='red')
plt.title('Row Run Time')
plt.xlabel('Number of Rows (log10)')
plt.ylabel('Time Taken (seconds)')
plt.xscale('log')
# Plot red dots at the data points
plt.scatter(num_rows, time_taken_wall, color='black')

# Dotted plots for User and System Time
plt.plot(num_rows, time_taken_usr, linestyle='dotted', color='black')
plt.plot(num_rows, time_taken_sys, linestyle='dotted', color='green')

legend_data = {'Wall Time': 'red', 'User Time': 'black', 'System Time': 'green'}
legend_labels = list(legend_data.keys())
legend_handles = [plt.Line2D([0], [0], color=color, marker='o', linestyle='') for color in legend_data.values()]
plt.legend(legend_handles, legend_labels, title='Time Type', loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Mix

# %%
mix_ = [(10,10), (100,100), (1000,1000), (10000,10000)]
mix_vals = [10, 100, 1000, 10000]
time_taken_wall = [0.022, 0.153, 6.26, 564]
time_taken_usr = [0.009, 0.164, 5.96, 536]
time_taken_sys = [0.009, 0.007, 0.392, 33.8]

mix_run = pd.DataFrame({'Dimensions': mix_, 'Wall Time (s)': time_taken_wall, 'User Time (s)': time_taken_usr, 'System Time (s)': time_taken_sys , 'Number of Features': mix_vals})
mix_run
# Out:
#        Dimensions  Wall Time (s)  User Time (s)  System Time (s)  \
# 0        (10, 10)          0.022          0.009            0.009
# 1      (100, 100)          0.153          0.164            0.007
# 2    (1000, 1000)          6.260          5.960            0.392
# 3  (10000, 10000)        564.000        536.000           33.800
#
#    Number of Features
# 0                  10
# 1                 100
# 2                1000
# 3               10000

# %%
plt.figure(figsize=(7, 5))
sns.lineplot(x='Number of Features', y='Wall Time (s)', data=mix_run, color='red')
plt.title('Mixed Run Time')
plt.xlabel('Feature and Row Dimensions (log10)')
plt.ylabel('Time Taken (seconds)')
plt.xscale('log')
# Plot red dots at the data points
plt.scatter([x[0] for x in mix_], time_taken_wall, color='black')

# Dotted plots for User and System Time
plt.plot([x[0] for x in mix_], time_taken_usr, linestyle='dotted', color='black')
plt.plot([x[0] for x in mix_], time_taken_sys, linestyle='dotted', color='green')

legend_data = {'Wall Time': 'red', 'User Time': 'black', 'System Time': 'green'}
legend_labels = list(legend_data.keys())
legend_handles = [plt.Line2D([0], [0], color=color, marker='o', linestyle='') for color in legend_data.values()]
plt.legend(legend_handles, legend_labels, title='Time Type', loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Together

# %% [markdown]
# Feature

# %%
feature_run_old = [0.061, 0.203, 0.502, 0.840, 5.2]
feature_run_new = [0.032, 0.042, 0.086, 0.343, 4.76]
num_features = [10, 100, 1000, 10000, 100000]

feature_run = pd.DataFrame({'Number of Features': num_features, 'Old Wall Time (s)': feature_run_old, 'New Wall Time (s)': feature_run_new})
feature_run
# Out:
#    Number of Features  Old Wall Time (s)  New Wall Time (s)
# 0                  10              0.061              0.032
# 1                 100              0.203              0.042
# 2                1000              0.502              0.086
# 3               10000              0.840              0.343
# 4              100000              5.200              4.760

# %%
plt.figure(figsize=(7, 5))
sns.lineplot(x='Number of Features', y='Old Wall Time (s)', data=feature_run, color='red')
sns.lineplot(x='Number of Features', y='New Wall Time (s)', data=feature_run, color='blue')
plt.title('Feature Run Time')
plt.xlabel('Number of Features (log10)')
plt.ylabel('Time Taken (seconds)')
plt.xscale('log')

# Plot red dots at the data points
plt.scatter(num_features, feature_run_new, color='black')
plt.scatter(num_features, feature_run_old, color='black')

legend_data = {'Old Wall Time': 'red', 'New Wall Time': 'blue'}
legend_labels = list(legend_data.keys())
legend_handles = [plt.Line2D([0], [0], color=color, marker='o', linestyle='') for color in legend_data.values()]
plt.legend(legend_handles, legend_labels, title='Time Type', loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# Row

# %%
feature_run_old = [0.062, 0.385, 5.3, 75, 1300]
feature_run_new = [0.027, 0.240, 0.714, 13.8, 586]
num_rows = [10, 100, 1000, 10000, 100000]

feature_run = pd.DataFrame({'Number of Rows': num_rows, 'Old Wall Time (s)': feature_run_old, 'New Wall Time (s)': feature_run_new})
feature_run
# Out:
#    Number of Rows  Old Wall Time (s)  New Wall Time (s)
# 0              10              0.062              0.027
# 1             100              0.385              0.240
# 2            1000              5.300              0.714
# 3           10000             75.000             13.800
# 4          100000           1300.000            586.000

# %%
plt.figure(figsize=(7, 5))
sns.lineplot(x='Number of Rows', y='Old Wall Time (s)', data=feature_run, color='red')
sns.lineplot(x='Number of Rows', y='New Wall Time (s)', data=feature_run, color='blue')
plt.title('Row Run Time')
plt.xlabel('Number of Rows (log10)')
plt.ylabel('Time Taken (seconds)')
plt.xscale('log')

# Plot black dots at the data points
plt.scatter(num_rows, feature_run_new, color='black')
plt.scatter(num_rows, feature_run_old, color='black')

legend_data = {'Old Wall Time': 'red', 'New Wall Time': 'blue'}
legend_labels = list(legend_data.keys())
legend_handles = [plt.Line2D([0], [0], color=color, marker='o', linestyle='') for color in legend_data.values()]
plt.legend(legend_handles, legend_labels, title='Time Type', loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# Mix

# %%
mix_vals = [10, 100, 1000, 10000]
mix_old = [0.078, 2.97, 57.7, 1212]
mix_new = [0.022, 0.153, 6.26, 564]

mix_run = pd.DataFrame({'Number of Features': mix_vals, 'Old Wall Time (s)': mix_old, 'New Wall Time (s)': mix_new})
mix_run
# Out:
#    Number of Features  Old Wall Time (s)  New Wall Time (s)
# 0                  10              0.078              0.022
# 1                 100              2.970              0.153
# 2                1000             57.700              6.260
# 3               10000           1212.000            564.000

# %%
plt.figure(figsize=(7, 5))
sns.lineplot(x='Number of Features', y='Old Wall Time (s)', data=mix_run, color='red')
sns.lineplot(x='Number of Features', y='New Wall Time (s)', data=mix_run, color='blue')
plt.title('Mixed Run Time')
plt.xlabel('Feature and Row Dimensions (log10)')
plt.ylabel('Time Taken (seconds)')
plt.xscale('log')

# Plot black dots at the data points
plt.scatter(mix_vals, mix_new, color='black')
plt.scatter(mix_vals, mix_old, color='black')

legend_data = {'Old Wall Time': 'red', 'New Wall Time': 'blue'}
legend_labels = list(legend_data.keys())
legend_handles = [plt.Line2D([0], [0], color=color, marker='o', linestyle='') for color in legend_data.values()]
plt.legend(legend_handles, legend_labels, title='Time Type', loc='upper left')

plt.tight_layout()
plt.show()
